# %%
'''Q1. What is multiprocessing in python? Why is it useful?

Multiprocessing refers to the ability of a system to support more than one processor at the same time. 
Applications in a multiprocessing system are broken to smaller routines that run independently. 
The operating system allocates these threads to the processors improving performance of the system.
multiprocessing is useful for making programs more efficient by dividing and assigning tasks to different processors.
Python’s multiprocessing module simplifies this further by serving as a high-level tool to increase your programs'
efficiency by assigning tasks to different processes.'''
# Out:
# "Q1. What is multiprocessing in python? Why is it useful?\n\nMultiprocessing refers to the ability of a system to support more than one processor at the same time. \nApplications in a multiprocessing system are broken to smaller routines that run independently. \nThe operating system allocates these threads to the processors improving performance of the system.\nmultiprocessing is useful for making programs more efficient by dividing and assigning tasks to different processors.\nPython’s multiprocessing module simplifies this further by serving as a high-level tool to increase your programs'\nefficiency by assigning tasks to different processes."

# %%
'''Q2. What are the differences between multiprocessing and multithreading?

    Multithreading in Python	                             Multiprocessing in Python
    1. It Implements the Concurrency.	                     1.It Implements the Parallelism.
    2.Python does not support multithreading
      in the case of parallel computing.	                 2.Python supports multiprocessing in the case of parallel computing.
    3.In multithreading, multiple threads at
      the same time are generated by a single process.	     3.In multiprocessing, multiple threads at the same time run across multiple cores.
    4.Multithreading can not be classified.	                 4.Multiprocessing can be classified such as symmetric or asymmetric.
'''
# Out:
# 'Q2. What are the differences between multiprocessing and multithreading?\n\n    Multithreading in Python\t                             Multiprocessing in Python\n    1. It Implements the Concurrency.\t                     1.It Implements the Parallelism.\n    2.Python does not support multithreading\n      in the case of parallel computing.\t                 2.Python supports multiprocessing in the case of parallel computing.\n    3.In multithreading, multiple threads at\n      the same time are generated by a single process.\t     3.In multiprocessing, multiple threads at the same time run across multiple cores.\n    4.Multithreading can not be classified.\t                 4.Multiprocessing can be classified such as symmetric or asymmetric.\n'

# %%
'''Q3. Write a python code to create a process using the multiprocessing module.'''

import multiprocessing

def sqr(n):
    print(n**2,"Done!!")
    
if __name__ == '__main__':
    m = multiprocessing.Process(target = sqr,args=[10])
    
m.start()
m.join()
# Out:
# 100 Done!!

# %%
'''Q4. What is a multiprocessing pool in python? Why is it used?

    In the Process class, we had to create processes explicitly. 
    However, the Pool class is more convenient, and you do not have 
    to manage it manually. The syntax to create a pool object is 
    multiprocessing.Pool(processes, initializer, initargs, maxtasksperchild, 
    context). All the arguments are optional. processes represent the number
    of worker processes you want to create. 
    Pool is used when tasks are independent of each other.
'''
# Out:
# 'Q4. What is a multiprocessing pool in python? Why is it used?\n\n    In the Process class, we had to create processes explicitly. \n    However, the Pool class is more convenient, and you do not have \n    to manage it manually. The syntax to create a pool object is \n    multiprocessing.Pool(processes, initializer, initargs, maxtasksperchild, \n    context). All the arguments are optional. processes represent the number\n    of worker processes you want to create. \n    Pool is used when tasks are independent of each other.\n'

# %%
'''Q5. How can we create a pool of worker processes in python using the multiprocessing module?

       The syntax to create a pool object is
       
       multiprocessing.Pool(processes,initializer,initargs,maxtasksperchild,context)
       
       All the arguments are optional. processes represent the number
       of worker processes you want to create.
       
       
'''
# Out:
# 'Q5. How can we create a pool of worker processes in python using the multiprocessing module?\n\n       The syntax to create a pool object is\n       \n       multiprocessing.Pool(processes,initializer,initargs,maxtasksperchild,context)\n       \n       All the arguments are optional. processes represent the number\n       of worker processes you want to create.\n       \n       \n'

# %%
'''Q6. Write a python program to create 4 processes, each process should print a different number using the
       multiprocessing module in python.'''
import multiprocessing

def printnum(n):
    print(n)
    
if __name__ == '__main__':
    with multiprocessing.Pool(processes = 4) as pool :
        out = pool.map(printnum,range(4))
        
out.start()
out.join()
# Out:
# 0213
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 12
#       9     with multiprocessing.Pool(processes = 4) as pool :
#      10         out = pool.map(printnum,range(4))
# ---> 12 out.start()
#      13 out.join()
#
# AttributeError: 'list' object has no attribute 'start'
